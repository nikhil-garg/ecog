# %%
import numpy as np
import math as m
import os
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

train_data={}
train_labels={}
locs={}
locs_2d={}
frames={}
images={}

# %%
from scipy.interpolate import griddata
from sklearn.preprocessing import scale

# %%
subjects=['bp',
    'ca',
    'cc',
    'de',
    'fp',
    'gc',
    'gf',
    'hh',
    'hl',
    'jc',
    'jf',
    'jm',
    'jp',
    'jt',
    'rh',
    'rr',
    'ug',
    'wc',
    'zt'
]

# %%
def cart2sph(x, y, z):
    """
    Transform Cartesian coordinates to spherical
    :param x: X coordinate
    :param y: Y coordinate
    :param z: Z coordinate
    :return: radius, elevation, azimuth
    """
    x2_y2 = x**2 + y**2
    r = m.sqrt(x2_y2 + z**2)                    # r
    elev = m.atan2(z, m.sqrt(x2_y2))            # Elevation
    az = m.atan2(y, x)                          # Azimuth
    return r, elev, az


def pol2cart(theta, rho):
    """
    Transform polar coordinates to Cartesian
    :param theta: angle value
    :param rho: radius value
    :return: X, Y
    """
    return rho * m.cos(theta), rho * m.sin(theta)

# %%
def azim_proj(pos):
    """
    Computes the Azimuthal Equidistant Projection of input point in 3D Cartesian Coordinates.
    Imagine a plane being placed against (tangent to) a globe. If
    a light source inside the globe projects the graticule onto
    the plane the result would be a planar, or azimuthal, map
    projection.

    :param pos: position in 3D Cartesian coordinates
    :return: projected coordinates using Azimuthal Equidistant Projection
    """
    [r, elev, az] = cart2sph(pos[0], pos[1], pos[2])
    return pol2cart(az, m.pi / 2 - elev)

# %%
path=os.path.join("..","epoched_data/motor_basic")
for sub in subjects:
    train_data[sub]=np.load(path+"/"+sub+"_mot_epochs.npz")['X']
    train_labels[sub]=np.load(path+"/"+sub+"_mot_epochs.npz")['y']

# %%
path_locs=os.path.join("..","motor_basic_npz_raw")
for sub in subjects:
    locs[sub]=np.load(path_locs+"/"+sub+"_mot.npz")['electrodes']

# %%
def get_averages(f,Y):
    low_alpha_range=(7,12)
    high_alpha_range=(10,13)
    beta_range=(14,25)
    low_gamma_range=(26,35)
    high_gamma_range=(36,70)
    beta = Y[(f>beta_range[0]) & (f<=beta_range[1])].mean()/100
    low_alpha = Y[(f>low_alpha_range[0]) & (f<=low_alpha_range[1])].mean()/100
    high_alpha = Y[(f>high_alpha_range[0]) & (f<=high_alpha_range[1])].mean()/100
    low_gamma = Y[(f>low_gamma_range[0]) & (f<=low_gamma_range[1])].mean()/100
    high_gamma = Y[(f>high_gamma_range[0]) & (f<=high_gamma_range[1])].mean()/100
    return low_alpha,high_alpha,beta,low_gamma,high_gamma

# %%
for sub in subjects:
    n_electrodes=locs[sub].shape[0]
    locs_2d[sub]=np.empty((n_electrodes,2))
    for i in range (n_electrodes):
        locs_2d[sub][i]=azim_proj(locs[sub][i])

# %%
def get_fft(snippet):
    Fs = 1000;  # sampling rate
    #Ts = len(snippet)/Fs/Fs; # sampling interval
    snippet_time = len(snippet)/Fs
    Ts = 1.0/Fs; # sampling interval
    t = np.arange(0,snippet_time,Ts) # time vector

    # ff = 5;   # frequency of the signal
    # y = np.sin(2*np.pi*ff*t)
    y = snippet
#     print('Ts: ',Ts)
#     print(t)
#     print(y.shape)
    n = len(y) # length of the signal
    k = np.arange(n)
    T = n/Fs
    frq = k/T # two sides frequency range
    frq = frq[range(n//2)] # one side frequency range

    Y = np.fft.fft(y)/n # fft computing and normalization
    Y = Y[range(n//2)]
    #Added in: (To remove bias.)
    #Y[0] = 0
    return frq,abs(Y)
#f,Y = get_fft(np.hanning(len(snippet))*snippet)

# %%
Fs=1000
image_size = 64
frame_duration = 3.0
overlap=0
frame_length = Fs * frame_duration

# %%
for sub in subjects:
    frames[sub] = []
    n_electrodes=train_data[sub].shape[1]
    for trial in range(train_data[sub].shape[0]):
        frame=[]
        for i in range (n_electrodes):
            snippet = train_data[sub][trial,i,:]
            f,Y =  get_fft(snippet)
            la, ha, b, lg, hg = get_averages(f,Y)
            frame.append([la, ha, b, lg, hg])
        frames[sub].append(frame)
    frames[sub]=np.array(frames[sub])

# %%
frames['bp']
# Out:
# array([[[0.61156519, 0.67253133, 0.37972937, 0.21930585, 0.12005414],
#         [0.4780272 , 0.44575872, 0.30019389, 0.1828456 , 0.11578361],
#         [1.19548536, 0.81989393, 0.43793013, 0.14342559, 0.09257395],
#         ...,
#         [0.89934715, 0.87293335, 0.37064674, 0.17643609, 0.08866591],
#         [1.05559722, 0.99615298, 0.45273453, 0.18923188, 0.11981511],
#         [1.45937131, 1.20889451, 0.4218755 , 0.23669631, 0.1265039 ]],
#
#        [[0.56189289, 0.49829043, 0.31968641, 0.19928478, 0.11942025],
#         [0.75526592, 0.57479568, 0.30391421, 0.166267  , 0.10026313],
#         [0.76541458, 0.7832127 , 0.30195337, 0.18460209, 0.09363034],
#         ...,
#         [0.89830231, 0.76261016, 0.47665726, 0.18492275, 0.10504374],
#         [1.09172056, 0.87285284, 0.31154663, 0.20447486, 0.12318371],
#         [1.04732371, 0.71303282, 0.43224054, 0.20208507, 0.13254414]],
#
#        [[0.80117161, 0.58382678, 0.41379011, 0.18826627, 0.14075787],
#         [0.76543972, 0.66783531, 0.32579026, 0.16412918, 0.11216628],
#         [0.72870141, 0.74443385, 0.3481664 , 0.1923183 , 0.09752507],
#         ...,
#         [0.85566077, 0.57878764, 0.36834379, 0.17458856, 0.09021685],
#         [1.59597991, 1.10864912, 0.47771089, 0.28178551, 0.17061296],
#         [1.42305342, 1.08186715, 0.41322243, 0.20197355, 0.11564705]],
#
#        ...,
#
#        [[1.17323985, 1.18814157, 0.42717043, 0.23950966, 0.1353614 ],
#         [1.31716812, 0.91342905, 0.50765451, 0.20018569, 0.12201063],
#         [1.23910934, 1.35035304, 0.60851164, 0.23530096, 0.11011429],
#         ...,
#         [0.70644204, 0.6823902 , 0.32097362, 0.17455713, 0.10014916],
#         [1.6013844 , 0.66858891, 0.49598802, 0.25753466, 0.12781572],
#         [1.16398231, 0.77890408, 0.43254298, 0.22336305, 0.12240582]],
#
#        [[0.75793474, 0.60432814, 0.39255014, 0.24175524, 0.13560541],
#         [0.78032446, 0.72247964, 0.31521289, 0.16983348, 0.11704283],
#         [1.00813134, 0.50027443, 0.32031645, 0.20181931, 0.096177  ],
#         ...,
#         [1.06201771, 0.74813901, 0.35771206, 0.12666587, 0.09586535],
#         [1.25796832, 0.69181497, 0.46682952, 0.25959319, 0.1477494 ],
#         [1.52873708, 0.80371644, 0.42789722, 0.21565444, 0.10440402]],
#
#        [[0.61813121, 0.40809849, 0.32746125, 0.2058805 , 0.12133349],
#         [0.77724143, 0.65603425, 0.35590865, 0.19589949, 0.11362483],
#         [0.95781217, 0.73480937, 0.28502247, 0.15819104, 0.08873574],
#         ...,
#         [1.05401136, 0.98091273, 0.44494575, 0.17597235, 0.12363979],
#         [1.09783943, 0.81678474, 0.3259102 , 0.17613941, 0.10999323],
#         [1.44422351, 0.85274563, 0.538613  , 0.27742907, 0.16501636]]])

# %%
def gen_images(locs, features, n_gridpoints, normalize=True,
               augment=False, pca=False, std_mult=0.1, n_components=2, edgeless=False):
    """
    Generates EEG images given electrode locations in 2D space and multiple feature values for each electrode

    :param locs: An array with shape [n_electrodes, 2] containing X, Y
                        coordinates for each electrode.
    :param features: Feature matrix as [n_samples, n_features]
                                Features are as columns.
                                Features corresponding to each frequency band are concatenated.
                                (alpha1, alpha2, ..., beta1, beta2,...)
    :param n_gridpoints: Number of pixels in the output images
    :param normalize:   Flag for whether to normalize each band over all samples
    :param augment:     Flag for generating augmented images
    :param pca:         Flag for PCA based data augmentation
    :param std_mult     Multiplier for std of added noise
    :param n_components: Number of components in PCA to retain for augmentation
    :param edgeless:    If True generates edgeless images by adding artificial channels
                        at four corners of the image with value = 0 (default=False).
    :return:            Tensor of size [samples, colors, W, H] containing generated
                        images.
    """
    feat_array_temp = []
    nElectrodes = locs.shape[0]     # Number of electrodes
    # Test whether the feature vector length is divisible by number of electrodes
    assert features.shape[1] % nElectrodes == 0
    n_colors = features.shape[1] // nElectrodes
    for c in range(int(n_colors)):
        feat_array_temp.append(features[:, c * nElectrodes : nElectrodes * (c+1)])
    nSamples = features.shape[0]
    # Interpolate the values
    grid_x, grid_y = np.mgrid[
                     min(locs[:, 0]):max(locs[:, 0]):n_gridpoints*1j,
                     min(locs[:, 1]):max(locs[:, 1]):n_gridpoints*1j
                     ]
    temp_interp = []
    for c in range(n_colors):
        temp_interp.append(np.zeros([nSamples, n_gridpoints, n_gridpoints]))
    # Generate edgeless images
    if edgeless:
        min_x, min_y = np.min(locs, axis=0)
        max_x, max_y = np.max(locs, axis=0)
        locs = np.append(locs, np.array([[min_x, min_y], [min_x, max_y],[max_x, min_y],[max_x, max_y]]),axis=0)
        for c in range(n_colors):
            feat_array_temp[c] = np.append(feat_array_temp[c], np.zeros((nSamples, 4)), axis=1)
    # Interpolating
    for i in range(nSamples):
        for c in range(n_colors):
            temp_interp[c][i, :, :] = griddata(locs, feat_array_temp[c][i, :], (grid_x, grid_y),
                                    method='cubic', fill_value=np.nan)
        print('Interpolating {0}/{1}\r'.format(i+1, nSamples), end='\r')
    # Normalizing
    for c in range(n_colors):
        if normalize:
            temp_interp[c][~np.isnan(temp_interp[c])] = \
                scale(temp_interp[c][~np.isnan(temp_interp[c])])
        temp_interp[c] = np.nan_to_num(temp_interp[c])
    return np.swapaxes(np.asarray(temp_interp), 0, 1)     # swap axes to have [samples, colors, W, H]

# %%
for sub in subjects:
    temp=frames[sub].reshape(len(frames[sub]),locs[sub].shape[0]*5)
    images[sub]=gen_images(locs_2d[sub],temp,image_size,normalize=False)
    images[sub]=np.swapaxes(images[sub],1,3)

# %%
for sub in subjects:
    path=os.getcwd()
    path=os.path.join(path,sub)
    os.makedirs(path)
    for i in range (len(images[sub])):
        plt.imsave(path+"/"+sub+"_"+str(i)+"_la.png",images[sub][i,:,:,0])
        plt.imsave(path+"/"+sub+"_"+str(i)+"_ha.png",images[sub][i,:,:,1])
        plt.imsave(path+"/"+sub+"_"+str(i)+"_b.png",images[sub][i,:,:,2])
        plt.imsave(path+"/"+sub+"_"+str(i)+"_lg.png",images[sub][i,:,:,3])
        plt.imsave(path+"/"+sub+"_"+str(i)+"_hg.png",images[sub][i,:,:,4])

# %%
X=images['ca']
y=train_labels['ca']
for i in range (len(y)):
    if y[i]>0:
        y[i]=y[i]-10

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# input image dimensions
img_rows, img_cols = 64,64

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

input_shape = (img_rows, img_cols, 5)

import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

batch_size = 16
num_classes =3
epochs = 100

# convert class vectors to binary class matrices
y_train = tensorflow.keras.utils.to_categorical(y_train, num_classes)
y_test = tensorflow.keras.utils.to_categorical(y_test, num_classes)


model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',input_shape=input_shape))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(10))
model.add(Activation('relu'))
# model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = tensorflow.keras.optimizers.RMSprop(lr=0.001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
#x_train /= 255
#x_test /= 255


model.fit(x_train, y_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(x_test, y_test),
        shuffle=True,verbose=2)
# Out:
# x_train shape: (90, 64, 64, 5)
# 90 train samples
# 31 test samples
# Epoch 1/100
# 6/6 - 1s - loss: 2.5331 - accuracy: 0.4444 - val_loss: 0.9704 - val_accuracy: 0.5806
# Epoch 2/100
# 6/6 - 0s - loss: 1.0565 - accuracy: 0.4778 - val_loss: 0.9550 - val_accuracy: 0.5806
# Epoch 3/100
# 6/6 - 0s - loss: 1.0546 - accuracy: 0.4778 - val_loss: 1.0128 - val_accuracy: 0.5806
# Epoch 4/100
# 6/6 - 0s - loss: 0.9979 - accuracy: 0.4778 - val_loss: 1.6260 - val_accuracy: 0.2258
# Epoch 5/100
# 6/6 - 0s - loss: 1.1420 - accuracy: 0.4111 - val_loss: 1.0421 - val_accuracy: 0.5484
# Epoch 6/100
# 6/6 - 0s - loss: 1.0108 - accuracy: 0.4889 - val_loss: 0.9334 - val_accuracy: 0.5806
# Epoch 7/100
# 6/6 - 0s - loss: 0.9748 - accuracy: 0.4778 - val_loss: 1.0009 - val_accuracy: 0.6129
# Epoch 8/100
# 6/6 - 0s - loss: 0.8976 - accuracy: 0.5111 - val_loss: 0.9010 - val_accuracy: 0.5806
# Epoch 9/100
# 6/6 - 0s - loss: 0.9002 - accuracy: 0.5000 - val_loss: 0.9917 - val_accuracy: 0.5484
# Epoch 10/100
# 6/6 - 0s - loss: 1.0055 - accuracy: 0.5778 - val_loss: 0.9668 - val_accuracy: 0.6129
# Epoch 11/100
# 6/6 - 0s - loss: 0.9016 - accuracy: 0.6111 - val_loss: 0.9353 - val_accuracy: 0.5806
# Epoch 12/100
# 6/6 - 0s - loss: 0.8954 - accuracy: 0.5778 - val_loss: 0.9293 - val_accuracy: 0.6129
# Epoch 13/100
# 6/6 - 0s - loss: 0.8704 - accuracy: 0.5556 - val_loss: 0.9060 - val_accuracy: 0.5806
# Epoch 14/100
# 6/6 - 0s - loss: 0.8096 - accuracy: 0.5667 - val_loss: 0.8502 - val_accuracy: 0.5484
# Epoch 15/100
# 6/6 - 0s - loss: 0.8232 - accuracy: 0.5667 - val_loss: 0.8306 - val_accuracy: 0.5484
# Epoch 16/100
# 6/6 - 0s - loss: 0.7640 - accuracy: 0.5333 - val_loss: 0.9360 - val_accuracy: 0.4839
# Epoch 17/100
# 6/6 - 0s - loss: 0.7487 - accuracy: 0.6111 - val_loss: 0.8761 - val_accuracy: 0.5484
# Epoch 18/100
# 6/6 - 0s - loss: 0.8448 - accuracy: 0.5667 - val_loss: 0.8272 - val_accuracy: 0.5484
# Epoch 19/100
# 6/6 - 0s - loss: 0.7250 - accuracy: 0.5556 - val_loss: 0.8414 - val_accuracy: 0.5484
# Epoch 20/100
# 6/6 - 0s - loss: 0.7521 - accuracy: 0.5778 - val_loss: 0.9430 - val_accuracy: 0.5806
# Epoch 21/100
# 6/6 - 0s - loss: 0.7117 - accuracy: 0.5778 - val_loss: 0.8411 - val_accuracy: 0.6129
# Epoch 22/100
# 6/6 - 0s - loss: 0.7047 - accuracy: 0.6111 - val_loss: 0.8453 - val_accuracy: 0.5806
# Epoch 23/100
# 6/6 - 0s - loss: 0.6815 - accuracy: 0.6222 - val_loss: 0.8637 - val_accuracy: 0.5484
# Epoch 24/100
# 6/6 - 0s - loss: 0.7954 - accuracy: 0.5444 - val_loss: 0.8559 - val_accuracy: 0.5484
# Epoch 25/100
# 6/6 - 0s - loss: 0.7265 - accuracy: 0.5889 - val_loss: 0.8112 - val_accuracy: 0.6129
# Epoch 26/100
# 6/6 - 0s - loss: 0.6315 - accuracy: 0.6111 - val_loss: 0.8951 - val_accuracy: 0.5484
# Epoch 27/100
# 6/6 - 0s - loss: 0.6810 - accuracy: 0.6667 - val_loss: 1.2044 - val_accuracy: 0.5484
# Epoch 28/100
# 6/6 - 0s - loss: 0.6987 - accuracy: 0.7000 - val_loss: 0.8290 - val_accuracy: 0.5806
# Epoch 29/100
# 6/6 - 0s - loss: 0.5945 - accuracy: 0.8000 - val_loss: 0.9059 - val_accuracy: 0.6774
# Epoch 30/100
# 6/6 - 0s - loss: 0.5570 - accuracy: 0.7889 - val_loss: 1.1603 - val_accuracy: 0.5161
# Epoch 31/100
# 6/6 - 0s - loss: 0.6800 - accuracy: 0.7111 - val_loss: 0.7637 - val_accuracy: 0.6129
# Epoch 32/100
# 6/6 - 0s - loss: 0.6000 - accuracy: 0.7778 - val_loss: 0.8955 - val_accuracy: 0.5161
# Epoch 33/100
# 6/6 - 0s - loss: 0.6110 - accuracy: 0.7778 - val_loss: 0.7555 - val_accuracy: 0.6774
# Epoch 34/100
# 6/6 - 0s - loss: 0.5559 - accuracy: 0.8000 - val_loss: 1.0132 - val_accuracy: 0.6129
# Epoch 35/100
# 6/6 - 0s - loss: 0.5402 - accuracy: 0.8333 - val_loss: 0.9508 - val_accuracy: 0.6129
# Epoch 36/100
# 6/6 - 0s - loss: 0.5087 - accuracy: 0.7778 - val_loss: 0.8265 - val_accuracy: 0.7097
# Epoch 37/100
# 6/6 - 0s - loss: 0.4925 - accuracy: 0.8444 - val_loss: 0.9056 - val_accuracy: 0.5484
# Epoch 38/100
# 6/6 - 0s - loss: 0.5432 - accuracy: 0.7667 - val_loss: 1.1344 - val_accuracy: 0.5161
# Epoch 39/100
# 6/6 - 0s - loss: 0.4928 - accuracy: 0.7667 - val_loss: 0.9752 - val_accuracy: 0.5161
# Epoch 40/100
# 6/6 - 0s - loss: 0.4420 - accuracy: 0.8444 - val_loss: 1.3872 - val_accuracy: 0.5806
# Epoch 41/100
# 6/6 - 0s - loss: 0.5150 - accuracy: 0.8333 - val_loss: 1.2357 - val_accuracy: 0.5484
# Epoch 42/100
# 6/6 - 0s - loss: 0.4566 - accuracy: 0.8000 - val_loss: 1.0091 - val_accuracy: 0.6774
# Epoch 43/100
# 6/6 - 0s - loss: 0.4323 - accuracy: 0.8778 - val_loss: 0.9120 - val_accuracy: 0.6129
# Epoch 44/100
# 6/6 - 0s - loss: 0.3834 - accuracy: 0.8778 - val_loss: 1.4670 - val_accuracy: 0.5484
# Epoch 45/100
# 6/6 - 0s - loss: 0.3467 - accuracy: 0.9000 - val_loss: 1.2014 - val_accuracy: 0.6129
# Epoch 46/100
# 6/6 - 0s - loss: 0.4570 - accuracy: 0.8222 - val_loss: 1.5772 - val_accuracy: 0.5806
# Epoch 47/100
# 6/6 - 0s - loss: 0.5100 - accuracy: 0.8222 - val_loss: 1.3080 - val_accuracy: 0.5484
# Epoch 48/100
# 6/6 - 0s - loss: 0.3761 - accuracy: 0.8778 - val_loss: 1.3053 - val_accuracy: 0.5806
# Epoch 49/100
# 6/6 - 0s - loss: 0.3570 - accuracy: 0.8889 - val_loss: 0.9941 - val_accuracy: 0.6129
# Epoch 50/100
# 6/6 - 0s - loss: 0.4247 - accuracy: 0.8778 - val_loss: 1.4130 - val_accuracy: 0.6129
# Epoch 51/100
# 6/6 - 0s - loss: 0.4050 - accuracy: 0.8778 - val_loss: 1.4781 - val_accuracy: 0.5806
# Epoch 52/100
# 6/6 - 0s - loss: 0.3223 - accuracy: 0.9000 - val_loss: 1.2277 - val_accuracy: 0.6452
# Epoch 53/100
# 6/6 - 0s - loss: 0.3525 - accuracy: 0.9000 - val_loss: 1.8158 - val_accuracy: 0.5484
# Epoch 54/100
# 6/6 - 0s - loss: 0.4319 - accuracy: 0.8778 - val_loss: 1.0428 - val_accuracy: 0.6129
# Epoch 55/100
# 6/6 - 0s - loss: 0.3666 - accuracy: 0.8778 - val_loss: 1.1601 - val_accuracy: 0.6129
# Epoch 56/100
# 6/6 - 0s - loss: 0.3034 - accuracy: 0.9222 - val_loss: 1.0831 - val_accuracy: 0.6129
# Epoch 57/100
# 6/6 - 0s - loss: 0.2942 - accuracy: 0.9333 - val_loss: 1.2490 - val_accuracy: 0.5806
# Epoch 58/100
# 6/6 - 0s - loss: 0.4871 - accuracy: 0.8111 - val_loss: 1.4016 - val_accuracy: 0.6129
# Epoch 59/100
# 6/6 - 0s - loss: 0.2849 - accuracy: 0.9333 - val_loss: 1.7362 - val_accuracy: 0.5484
# Epoch 60/100
# 6/6 - 0s - loss: 0.3008 - accuracy: 0.9000 - val_loss: 1.1789 - val_accuracy: 0.6129
# Epoch 61/100
# 6/6 - 0s - loss: 0.2811 - accuracy: 0.9444 - val_loss: 1.9848 - val_accuracy: 0.5484
# Epoch 62/100
# 6/6 - 0s - loss: 0.4040 - accuracy: 0.8667 - val_loss: 1.5627 - val_accuracy: 0.4839
# Epoch 63/100
# 6/6 - 0s - loss: 0.3146 - accuracy: 0.9111 - val_loss: 1.3174 - val_accuracy: 0.6129
# Epoch 64/100
# 6/6 - 0s - loss: 0.3069 - accuracy: 0.9111 - val_loss: 1.5744 - val_accuracy: 0.5161
# Epoch 65/100
# 6/6 - 0s - loss: 0.3142 - accuracy: 0.9444 - val_loss: 1.1109 - val_accuracy: 0.6452
# Epoch 66/100
# 6/6 - 0s - loss: 0.2651 - accuracy: 0.9111 - val_loss: 1.2120 - val_accuracy: 0.5806
# Epoch 67/100
# 6/6 - 0s - loss: 0.2614 - accuracy: 0.9667 - val_loss: 2.0922 - val_accuracy: 0.5484
# Epoch 68/100
# 6/6 - 0s - loss: 0.4075 - accuracy: 0.8333 - val_loss: 1.2620 - val_accuracy: 0.5806
# Epoch 69/100
# 6/6 - 0s - loss: 0.2600 - accuracy: 0.9444 - val_loss: 1.4800 - val_accuracy: 0.6452
# Epoch 70/100
# 6/6 - 0s - loss: 0.3067 - accuracy: 0.9556 - val_loss: 1.2408 - val_accuracy: 0.5484
# Epoch 71/100
# 6/6 - 0s - loss: 0.3322 - accuracy: 0.8889 - val_loss: 1.5127 - val_accuracy: 0.6129
# Epoch 72/100
# 6/6 - 0s - loss: 0.2477 - accuracy: 0.9444 - val_loss: 1.5546 - val_accuracy: 0.6452
# Epoch 73/100
# 6/6 - 0s - loss: 0.2543 - accuracy: 0.9222 - val_loss: 0.8809 - val_accuracy: 0.6452
# Epoch 74/100
# 6/6 - 0s - loss: 0.2993 - accuracy: 0.9333 - val_loss: 1.7952 - val_accuracy: 0.4516
# Epoch 75/100
# 6/6 - 0s - loss: 0.3353 - accuracy: 0.8889 - val_loss: 1.2212 - val_accuracy: 0.5806
# Epoch 76/100
# 6/6 - 0s - loss: 0.2402 - accuracy: 0.9556 - val_loss: 1.4218 - val_accuracy: 0.6129
# Epoch 77/100
# 6/6 - 0s - loss: 0.2518 - accuracy: 0.9667 - val_loss: 1.9209 - val_accuracy: 0.5806
# Epoch 78/100
# 6/6 - 0s - loss: 0.2402 - accuracy: 0.9556 - val_loss: 1.7513 - val_accuracy: 0.6452
# Epoch 79/100
# 6/6 - 0s - loss: 0.2716 - accuracy: 0.9222 - val_loss: 2.4653 - val_accuracy: 0.5806
# Epoch 80/100
# 6/6 - 0s - loss: 0.7642 - accuracy: 0.8333 - val_loss: 1.6859 - val_accuracy: 0.5806
# Epoch 81/100
# 6/6 - 0s - loss: 0.2167 - accuracy: 0.9667 - val_loss: 1.3015 - val_accuracy: 0.6129
# Epoch 82/100
# 6/6 - 0s - loss: 0.2147 - accuracy: 0.9667 - val_loss: 1.6867 - val_accuracy: 0.5806
# Epoch 83/100
# 6/6 - 0s - loss: 0.2087 - accuracy: 0.9778 - val_loss: 1.5581 - val_accuracy: 0.6129
# Epoch 84/100
# 6/6 - 0s - loss: 0.2085 - accuracy: 0.9667 - val_loss: 1.0766 - val_accuracy: 0.5806
# Epoch 85/100
# 6/6 - 0s - loss: 0.2121 - accuracy: 0.9889 - val_loss: 1.9410 - val_accuracy: 0.5484
# Epoch 86/100
# 6/6 - 0s - loss: 0.2456 - accuracy: 0.9222 - val_loss: 1.5216 - val_accuracy: 0.6452
# Epoch 87/100
# 6/6 - 0s - loss: 0.2593 - accuracy: 0.9556 - val_loss: 1.1963 - val_accuracy: 0.6129
# Epoch 88/100
# 6/6 - 0s - loss: 0.2466 - accuracy: 0.9111 - val_loss: 1.4973 - val_accuracy: 0.6129
# Epoch 89/100
# 6/6 - 0s - loss: 0.2299 - accuracy: 0.9444 - val_loss: 1.2208 - val_accuracy: 0.6129
# Epoch 90/100
# 6/6 - 0s - loss: 0.2038 - accuracy: 0.9889 - val_loss: 1.6630 - val_accuracy: 0.6452
# Epoch 91/100
# 6/6 - 0s - loss: 0.3772 - accuracy: 0.8889 - val_loss: 1.5862 - val_accuracy: 0.6452
# Epoch 92/100
# 6/6 - 0s - loss: 0.2255 - accuracy: 0.9333 - val_loss: 2.1257 - val_accuracy: 0.5806
# Epoch 93/100
# 6/6 - 0s - loss: 0.2787 - accuracy: 0.9556 - val_loss: 1.3553 - val_accuracy: 0.6129
# Epoch 94/100
# 6/6 - 0s - loss: 0.2219 - accuracy: 0.9778 - val_loss: 1.8908 - val_accuracy: 0.6452
# Epoch 95/100
# 6/6 - 0s - loss: 0.1904 - accuracy: 0.9556 - val_loss: 1.8656 - val_accuracy: 0.6129
# Epoch 96/100
# 6/6 - 0s - loss: 0.1861 - accuracy: 0.9667 - val_loss: 1.8081 - val_accuracy: 0.6129
# Epoch 97/100
# 6/6 - 0s - loss: 0.1891 - accuracy: 0.9889 - val_loss: 1.9472 - val_accuracy: 0.6129
# Epoch 98/100
# 6/6 - 0s - loss: 0.2610 - accuracy: 0.9333 - val_loss: 1.8172 - val_accuracy: 0.6129
# Epoch 99/100
# 6/6 - 0s - loss: 0.1947 - accuracy: 0.9889 - val_loss: 1.3370 - val_accuracy: 0.6129
# Epoch 100/100
# 6/6 - 0s - loss: 0.1911 - accuracy: 0.9889 - val_loss: 1.9109 - val_accuracy: 0.6129
