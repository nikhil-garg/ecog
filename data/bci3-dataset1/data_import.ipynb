# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import scipy.io as sio
from tempfile import TemporaryFile
pd.pandas.set_option('display.max_columns', None)
# %matplotlib inline

#import pandas_profiling as pdp

# %%
traindata=pd.DataFrame()
testdata=pd.DataFrame()
trainY=pd.DataFrame()

# %%
# traindata=pd.read_csv("train_data.csv",header=None)
# testdata=pd.read_csv("test_data.csv",header=None)
# trainY=pd.read_csv("train_labels.csv",header=None)

# %%
matlab_train=sio.loadmat('Competition_train.mat')
matlab_test=sio.loadmat('Competition_test.mat')

# %%
X_train=matlab_train['X']
y_train=matlab_train['Y']
X_test=matlab_test['X']

# %%
np.savez_compressed("bci_3.npz",X=X_train,events=y_train,X_test=X_test)

# %%
testplot=X_train[0,:,:]

# %%
for i in range(0,64):
    plt.subplot(64,1,i+1)
    plt.plot(testplot[i])
plt.tight_layout(pad=3)
# Out:
# <ipython-input-19-151b2ce81dce>:4: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   plt.tight_layout(pad=3)
